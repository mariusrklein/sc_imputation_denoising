# %% [markdown]
# # Generation of linex networks based on detected lipid ions

# %%
import os
import ast
import pandas as pd
import numpy as np
import networkx as nx

import linex2metaspace as lx2m
# Out:
# Package 'lynx' (LipidLynxX) not available. Lipid name conversions will not be possible.

# %%
from pandarallel import pandarallel
pandarallel.initialize(nb_workers=19, progress_bar=True, use_memory_fs=False)
# Out:
# INFO: Pandarallel will run on 19 workers.
# INFO: Pandarallel will use standard multiprocessing data transfer (pipe) to transfer data between the main process and workers.

# %%
# importing custom functions for imputation and evaluation
import sys

sys.path.append("/home/mklein/sc_imputation_denoising")

from sc_imputation_denoising.evaluation.evaluation_workflow import (
    evaluation_workflow,
)
# Out:
# IE version 1.2

# %%
# this folder contains all connectivities, plots, graphs etc.
main_path = '/home/mklein/Dropouts/linex'

# %%
# global prep
ref_lip_dict = lx2m.get_lx2_ref_lip_dict()
class_reacs = lx2m.get_organism_combined_class_reactions(ref_lip_dict=ref_lip_dict, organism='HSA')

# %%
from tqdm import tqdm

def multi_to_single_graph(multi_graph):
    # Create a new empty nx.Graph
    graph = nx.Graph()

    # Add all nodes from the original MultiGraph to the new Graph
    graph.add_nodes_from(multi_graph.nodes())

    # Iterate through all edges in the MultiGraph and add them to the new Graph
    for u, v, data in multi_graph.edges(data=True):
        # Check if an edge already exists between the nodes in the new Graph
        if not graph.has_edge(u, v):
            # If not, add the edge to the new Graph
            data = {k:str(v) for k, v in data.items()}
            graph.add_edge(u, v, **data)

    return graph

# %%
dataset = "Lx_Glioblastoma"

# %%
datasets = dict(
    Mx_Seahorse=dict(c=0.1, i=0.2, repl=1, cond=4),
    Lx_Pancreatic_Cancer=dict(c=0.2, i=0.05, repl=1, cond=4),
    Lx_Glioblastoma=dict(c=0.05, i=0.05, repl=4, cond=6),
    Lx_HepaRG=dict(c=0.2, i=0.2, repl=5, cond=4),
)

# %%
params = datasets[dataset]
max_fdr = 1

# %%
ds_config = f"{dataset}_cond{params['cond']}_mnar_c{params['c']}_i{params['i']}_fdr1_repl{params['repl']}"
repl=params['repl']
print(ds_config)
# Out:
# Lx_HepaRG_cond4_mnar_c0.2_i0.2_fdr1_repl5

# %%
wflow = evaluation_workflow.get_from_pickle(f'/scratch/klein/temp/evaluation_pickle_{ds_config}_{repl}.pkl')

# %%
adata = wflow.dataset

mol_names = 'moleculeNames'
if type(adata.var[mol_names][0]) is str:
    app_list = []
    for i in adata.var.index:
        app_list.append(ast.literal_eval(adata.var.loc[i, mol_names]))
    adata.var[mol_names] = pd.Series(app_list, index=adata.var.index)
assert type(adata.var[mol_names][0]) is list

# TODO should linex networks be constructed using filtered anndata matrices or not?
print(adata.shape)
# sc.pp.filter_genes(adata, min_cells=140)
print(adata.shape)

# %%
wflow.dataset.var
# Out:
#                  annotation_id      formula adduct  ON_sample  \
# annotation_id
# C10H21NO4+K        C10H21NO4+K    C10H21NO4     +K       True
# C12H15N5O3+K      C12H15N5O3+K   C12H15N5O3     +K       True
# C13H17NO3+Na      C13H17NO3+Na    C13H17NO3    +Na       True
# C14H17NO4+K        C14H17NO4+K    C14H17NO4     +K       True
# C14H19NO5+K        C14H19NO5+K    C14H19NO5     +K       True
# ...                        ...          ...    ...        ...
# C57H110O13P+H    C57H110O13P+H  C57H110O13P     +H       True
# C57H110O13P+Na  C57H110O13P+Na  C57H110O13P    +Na       True
# C57H111O13P+Na  C57H111O13P+Na  C57H111O13P    +Na       True
# C59H98O6+H          C59H98O6+H     C59H98O6     +H       True
# C59H100O6+Na      C59H100O6+Na    C59H100O6    +Na       True
#
#                                                      moleculeName  \
# annotation_id
# C10H21NO4+K                                             Miglustat
# C12H15N5O3+K                                            Entecavir
# C13H17NO3+Na                                         Lophophorine
# C14H17NO4+K     3-(4-hydroxy-3-methoxyphenyl)-N-(4-oxobutyl)pr...
# C14H19NO5+K                                      Harzianopyridone
# ...                                                           ...
# C57H110O13P+H                                            PI(48:0)
# C57H110O13P+Na                                           PI(48:0)
# C57H111O13P+Na                      phosphatidylinositol 48:0(1-)
# C59H98O6+H                                               TG(56:8)
# C59H100O6+Na                                             TG(56:7)
#
#                moleculeClass  fdr  n_cells
# annotation_id
# C10H21NO4+K                     1    16421
# C12H15N5O3+K                    1    17419
# C13H17NO3+Na                    1    16418
# C14H17NO4+K                     1    22616
# C14H19NO5+K                     1    27187
# ...                      ...  ...      ...
# C57H110O13P+H             PI    1     6161
# C57H110O13P+Na            PI    1     7249
# C57H111O13P+Na                  1    10589
# C59H98O6+H                TG    1     7111
# C59H100O6+Na              TG    1    13689
#
# [314 rows x 8 columns]

# %%
def create_linex_network(row):
    
    graph_path = os.path.join(row['save_to'] + '.graphml')
    if not os.path.exists(os.path.dirname(graph_path)):
        os.makedirs(os.path.dirname(graph_path))
    adata = row['adata']

    mol_names = 'moleculeNames'
    if type(adata.var[mol_names][0]) is str:
        app_list = []
        for i in adata.var.index:
            app_list.append(ast.literal_eval(adata.var.loc[i, mol_names]))
        adata.var[mol_names] = pd.Series(app_list, index=adata.var.index)
    assert type(adata.var[mol_names][0]) is list

    # LINEX2 preprocessing
    parsed_lipids = lx2m.parse_annotation_series(adata.var[mol_names], 
                                                ref_lip_dict, 
                                                verbose=True) # True if you want to see all lipids that were not parsed

    keep_annotations = lx2m.annotations_parsed_lipids(parsed_lipids)
    parsed_annotations = adata.var.copy()
    parsed_annotations['parsed_lipids'] = parsed_lipids
    parsed_annotations = parsed_annotations.loc[keep_annotations,:] 

    bootstraps = 30

    net = lx2m.bootstrap_networks(
            lx2m.unique_sum_species(parsed_annotations['parsed_lipids']),
            parsed_annotations['parsed_lipids'],
            n=bootstraps,
            lx2_class_reacs=class_reacs,
            lx2_reference_lipids=lx2m.get_lx2_ref_lips(),
            return_composed=True
        ) 

    ion_net = lx2m.ion_weight_graph(net, 
        lx2m.unique_sum_species(parsed_annotations['parsed_lipids']), 
        bootstraps=bootstraps,
        parsed_lipids=parsed_annotations['parsed_lipids'],
        #feature_similarity=feature_sim
    )

    single_ion_net = multi_to_single_graph(ion_net)

    nx.write_graphml(single_ion_net, graph_path)
    
    try:
        _ = nx.read_graphml(graph_path)
    except:
        return np.nan
    
    return graph_path

# %%
linex_path = create_linex_network(pd.Series({'save_to': os.path.join(main_path, dataset), 'adata': adata}))
# Out:
# Could not parse: 'C8HF15O2'
# Could not parse: 'C8HF15O2'
# Could not parse: 'C14H29O9P'
# Could not parse: 'C15H29O10P'
# Could not parse: 'C16H21N3O8S'
# Could not parse: 'C16H31O10P'
# Could not parse: 'C16H31O10P'
# Could not parse: 'C17H33O10P'
# Could not parse: 'C17H34NO8P'
# Could not parse: 'C17H34NO8P'
# Could not parse: 'C18H22N2O8'
# Could not parse: 'C18H22N2O8'
# Could not parse: 'C18H34NO10P'
# Could not parse: 'C19H24N2O8'
# Could not parse: 'C19H24N2O8'
# Could not parse: 'C19H24N2O8'
# Could not parse: 'C19H26O10'
# Could not parse: 'C19H27N3O9S'
# Could not parse: 'C19H27NO7S'
# Could not parse: 'C19H35NO6'
# Could not parse: 'C20H15F3N4O3'
# Could not parse: 'C20H15F3N4O3'
# Could not parse: 'C21H20O9'
# Could not parse: 'C21H20O9'
# Could not parse: 'C21H21NO7'
# Could not parse: 'C21H24N2O4S'
# Could not parse: 'C21H31N5O3'
# Could not parse: 'C21H37NO6'
# Could not parse: 'C21H39O6P'
# Could not parse: 'C21H39O6P'
# Could not parse: 'C22H24N2O8'
# Could not parse: 'C22H24N2O8'
# Could not parse: 'C22H29N3O13S'
# Could not parse: 'C22H29N3O13S'
# Could not parse: 'C22H44NO6P'
# Could not parse: 'C22H46NO7P'
# Could not parse: 'C23H20N2O3S'
# Could not parse: 'C23H23O13'
# Could not parse: 'C23H24O15'
# Could not parse: 'C23H34N4O10S'
# Could not parse: 'C23H40O4'
# Could not parse: 'C23H41O6P'
# Could not parse: 'C23H46NO6P'
# Could not parse: 'C23H46NO8P'
# Could not parse: 'C23H46NO8P'
# Could not parse: 'C24H43O8P'
# Could not parse: 'C24H48NO6P'
# Could not parse: 'C24H48NO6P'
# Could not parse: 'C24H48NO7P'
# Could not parse: 'C24H48NO7P'
# Could not parse: 'C24H50NO7P'
# Could not parse: 'C24H50NO7P'
# Could not parse: 'C24H52NO6P'
# Could not parse: 'C25H25N3O12S'
# Could not parse: 'C25H25N3O12S'
# Could not parse: 'C25H30O14'
# Could not parse: 'C25H46NO7P'
# Could not parse: 'C25H47NO4'
# Could not parse: 'C25H47NO6'
# Could not parse: 'C25H48NO8P'
# Could not parse: 'C25H48NO8P'
# Could not parse: 'C25H48NO9P'
# Could not parse: 'C25H50NO6P'
# Could not parse: 'C25H50NO8P'
# Could not parse: 'C25H50NO8P'
# Could not parse: 'C26H30O13'
# Could not parse: 'C26H30O13'
# Could not parse: 'C26H48NO7P'
# Could not parse: 'C26H48NO10P'
# Could not parse: 'C26H48NO10P'
# Could not parse: 'C26H48O6'
# Could not parse: 'C26H50NO6P'
# Could not parse: 'C26H51NO3'
# Could not parse: 'C26H52NO6P'
# Could not parse: 'C26H52NO7P'
# Could not parse: 'C26H52NO7P'
# Could not parse: 'C26H53NO4'
# Could not parse: 'C26H54NO7P'
# Could not parse: 'C26H54NO7P'
# Could not parse: 'C27H43NO4'
# Could not parse: 'C27H46O4S'
# Could not parse: 'C27H48NO8P'
# Could not parse: 'C27H50NO8P'
# Could not parse: 'C27H51NO4'
# Could not parse: 'C27H52NO8P'
# Could not parse: 'C27H52NO8P'
# Could not parse: 'C28H36N2O7'
# Could not parse: 'C28H38O3'
# Could not parse: 'C28H50NO7P'
# Could not parse: 'C28H52NO7P'
# Could not parse: 'C28H52NO10P'
# Could not parse: 'C28H52NO10P'
# Could not parse: 'C28H54NO8P'
# Could not parse: 'C28H54NO8P'
# Could not parse: 'C29H45NO3'
# Could not parse: 'C29H45NO4'
# Could not parse: 'C29H47NO4'
# Could not parse: 'C29H50NO8P'
# Could not parse: 'C29H50NO10P'
# Could not parse: 'C29H54NO8P'
# Could not parse: 'C29H56NO8P'
# Could not parse: 'C29H56NO8P'
# Could not parse: 'C29H56NO9P'
# Could not parse: 'C29H56NO9P'
# Could not parse: 'C29H56NO10P'
# Could not parse: 'C30H33O19S'
# Could not parse: 'C30H45NO5'
# Could not parse: 'C30H58NO8P'
# Could not parse: 'C30H58NO8P'
# Could not parse: 'C30H58NO9P'
# Could not parse: 'C30H58NO9P'
# Could not parse: 'C31H52NO10P'
# Could not parse: 'C31H54NO8P'
# Could not parse: 'C31H54NO10P'
# Could not parse: 'C31H58NO10P'
# Could not parse: 'C31H60NO8P'
# Could not parse: 'C31H60NO8P'
# Could not parse: 'C31H60NO9P'
# Could not parse: 'C31H60NO9P'
# Could not parse: 'C31H60NO10P'
# Could not parse: 'C32H49NO5'
# Could not parse: 'C32H56NO10P'
# Could not parse: 'C32H57O9P'
# Could not parse: 'C32H62NO8P'
# Could not parse: 'C32H62NO8P'
# Could not parse: 'C32H62NO9P'
# Could not parse: 'C32H62NO9P'
# Could not parse: 'C32H64NO8P'
# Could not parse: 'C32H64NO8P'
# Could not parse: 'C33H56NO10P'
# Could not parse: 'C33H62NO9P'
# Could not parse: 'C33H62NO9P'
# Could not parse: 'C33H62NO10P'
# Could not parse: 'C33H62O4'
# Could not parse: 'C33H64NO9P'
# Could not parse: 'C33H64NO9P'
# Could not parse: 'C33H64NO9P'
# Could not parse: 'C33H64NO10P'
# Could not parse: 'C33H64NO10P'
# Could not parse: 'C33H66NO8P'
# Could not parse: 'C33H66NO8P'
# Could not parse: 'C34H54O11'
# Could not parse: 'C34H58NO10P'
# Could not parse: 'C34H64NO9P'
# Could not parse: 'C34H66NO9P'
# Could not parse: 'C34H66NO9P'
# Could not parse: 'C34H67NO2'
# Could not parse: 'C35H60NO10P'
# Could not parse: 'C35H64O4'
# Could not parse: 'C35H65NO8'
# Could not parse: 'C35H66NO9P'
# Could not parse: 'C35H66NO9P'
# Could not parse: 'C35H66NO10P'
# Could not parse: 'C35H66NO10P'
# Could not parse: 'C35H66O4'
# Could not parse: 'C35H67O8P'
# Could not parse: 'C35H68NO9P'
# Could not parse: 'C35H68NO9P'
# Could not parse: 'C35H68NO10P'
# Could not parse: 'C35H68NO10P'
# Could not parse: 'C35H70NO8P'
# Could not parse: 'C35H70NO8P'
# Could not parse: 'C36H56O11'
# Could not parse: 'C36H70NO6P'
# Could not parse: 'C36H72NO6P'
# Could not parse: 'C36H72NO8P'
# Could not parse: 'C36H72NO8P'
# Could not parse: 'C37H64NO9P'
# Could not parse: 'C37H64NO10P'
# Could not parse: 'C37H66NO10P'
# Could not parse: 'C37H66O4'
# Could not parse: 'C37H67NO8'
# Could not parse: 'C37H68O4'
# Could not parse: 'C37H69NO8'
# Could not parse: 'C37H69O8P'
# Could not parse: 'C37H70NO9P'
# Could not parse: 'C37H70NO9P'
# Could not parse: 'C37H71NO6'
# Could not parse: 'C37H71O8P'
# Could not parse: 'C37H75N2O6P'
# Could not parse: 'C38H55NO7'
# Could not parse: 'C38H68NO6P'
# Could not parse: 'C38H74NO8P'
# Could not parse: 'C38H74NO8P'
# Could not parse: 'C38H76NO8P'
# Could not parse: 'C38H76NO8P'
# Could not parse: 'C38H77O9P'
# Could not parse: 'C38H78NO7P'
# Could not parse: 'C38H78NO7P'
# Could not parse: 'C39H38O20'
# Could not parse: 'C39H61O8P'
# Could not parse: 'C39H67O8P'
# Could not parse: 'C39H68NO9P'
# Could not parse: 'C39H68O4'
# Could not parse: 'C39H69O8P'
# Could not parse: 'C39H70O4'
# Could not parse: 'C39H71O8P'
# Could not parse: 'C39H72N2O15'
# Could not parse: 'C39H72O4'
# Could not parse: 'C39H73O8P'
# Could not parse: 'C39H73O8P'
# Could not parse: 'C39H75O7P'
# Could not parse: 'C39H76NO8P'
# Could not parse: 'C39H76NO8P'
# Could not parse: 'C39H78NO8P'
# Could not parse: 'C39H78NO8P'
# Could not parse: 'C39H79N2O6P'
# Could not parse: 'C39H79N2O6P'
# Could not parse: 'C39H80N2O6P'
# Could not parse: 'C39H81N2O6P'
# Could not parse: 'C39H81N2O6P'
# Could not parse: 'C39H82N2O6P'
# Could not parse: 'C40H56O6S'
# Could not parse: 'C40H69NO4'
# Could not parse: 'C40H74NO8P'
# Could not parse: 'C40H76NO8P'
# Could not parse: 'C40H78NO8P'
# Could not parse: 'C40H78NO8P'
# Could not parse: 'C40H78NO10P'
# Could not parse: 'C40H80N2O6P'
# Could not parse: 'C40H80NO7P'
# Could not parse: 'C40H80NO7P'
# Could not parse: 'C40H80NO8P'
# Could not parse: 'C40H80NO8P'
# Could not parse: 'C40H82NO7P'
# Could not parse: 'C40H82NO7P'
# Could not parse: 'C41H68O11'
# Could not parse: 'C41H69O8P'
# Could not parse: 'C41H70O4'
# Could not parse: 'C41H71O8P'
# Could not parse: 'C41H73O8P'
# Could not parse: 'C41H75O8P'
# Could not parse: 'C41H76NO8P'
# Could not parse: 'C41H77N2O6P'
# Could not parse: 'C41H77O8P'
# Could not parse: 'C41H78NO8P'
# Could not parse: 'C41H78NO8P'
# Could not parse: 'C41H79N2O6P'
# Could not parse: 'C41H80NO8P'
# Could not parse: 'C41H80NO8P'
# Could not parse: 'C41H82NO7P'
# Could not parse: 'C41H82NO8P'
# Could not parse: 'C41H84N2O6P'
# Could not parse: 'C42H61NO7'
# Could not parse: 'C42H68O13'
# Could not parse: 'C42H76NO8P'
# Could not parse: 'C42H78NO7P'
# Could not parse: 'C42H78NO8P'
# Could not parse: 'C42H80NO7P'
# Could not parse: 'C42H80NO8P'
# Could not parse: 'C42H80NO8P'
# Could not parse: 'C42H82NO7P'
# Could not parse: 'C42H82NO8P'
# Could not parse: 'C42H82NO8P'
# Could not parse: 'C42H82NO8P'
# Could not parse: 'C42H82NO11P'
# Could not parse: 'C42H82NO11P'
# Could not parse: 'C42H84NO7P'
# Could not parse: 'C42H84NO7P'
# Could not parse: 'C42H84NO8P'
# Could not parse: 'C43H73O8P'
# Could not parse: 'C43H74NO9P'
# Could not parse: 'C43H75NO4'
# Could not parse: 'C43H75O8P'
# Could not parse: 'C43H76NO8P'
# Could not parse: 'C43H78NO8P'
# Could not parse: 'C43H80NO8P'
# Could not parse: 'C43H82NO8P'
# Could not parse: 'C43H82NO8P'
# Could not parse: 'C43H84NO8P'
# Could not parse: 'C43H84NO8P'
# Could not parse: 'C43H84NO10P'
# Could not parse: 'C43H86NO7P'
# Could not parse: 'C44H72O13'
# Could not parse: 'C44H78NO8P'
# Could not parse: 'C44H80NO8P'
# Could not parse: 'C44H82NO7P'
# Could not parse: 'C44H82NO8P'
# Could not parse: 'C44H82NO8P'
# Could not parse: 'C44H83NO9'
# Could not parse: 'C44H84NO8P'
# Could not parse: 'C44H84NO8P'
# Could not parse: 'C44H86NO7P'
# Could not parse: 'C44H86NO7P'
# Could not parse: 'C44H86NO8P'
# Could not parse: 'C44H86NO8P'
# Could not parse: 'C45H77NO9'
# Could not parse: 'C45H78NO7P'
# Could not parse: 'C45H79NO4'
# Could not parse: 'C45H80NO8P'
# Could not parse: 'C45H82NO8P'
# Could not parse: 'C45H82NO10P'
# Could not parse: 'C45H84NO8P'
# Could not parse: 'C45H86NO8P'
# Could not parse: 'C45H86NO10P'
# Could not parse: 'C45H88NO8P'
# Could not parse: 'C45H88NO10P'
# Could not parse: 'C46H80NO8P'
# Could not parse: 'C46H82NO8P'
# Could not parse: 'C46H84NO7P'
# Could not parse: 'C46H84NO8P'
# Could not parse: 'C46H88NO8P'
# Could not parse: 'C46H89O8P'
# Could not parse: 'C46H90NO12P'
# Could not parse: 'C46H91O8P'
# Could not parse: 'C46H92NO12P'
# Could not parse: 'C47H79NO8'
# Could not parse: 'C47H81NO9'
# Could not parse: 'C47H82O10'
# Could not parse: 'C47H83NO8'
# Could not parse: 'C47H84NO7P'
# Could not parse: 'C47H84NO10P'
# Could not parse: 'C47H86NO10P'
# Could not parse: 'C47H90NO10P'
# Could not parse: 'C47H93N2O6P'
# Could not parse: 'C47H93N2O6P'
# Could not parse: 'C47H95N2O6P'
# Could not parse: 'C48H82NO8P'
# Could not parse: 'C48H83NO9'
# Could not parse: 'C48H83NO9'
# Could not parse: 'C48H85NO9'
# Could not parse: 'C48H93O13P'
# Could not parse: 'C48H94NO12P'
# Could not parse: 'C48H96NO12P'
# Could not parse: 'C49H85NO8'
# Could not parse: 'C49H85NO9'
# Could not parse: 'C49H85O7P'
# Could not parse: 'C49H86NO10P'
# Could not parse: 'C49H87NO8'
# Could not parse: 'C49H87O7P'
# Could not parse: 'C49H88NO7P'
# Could not parse: 'C49H88NO10P'
# Could not parse: 'C49H93NO8'
# Could not parse: 'C49H94O13P2'
# Could not parse: 'C51H87NO8'
# Could not parse: 'C51H89NO8'
# Could not parse: 'C51H89O9P'
# Could not parse: 'C51H90NO7P'
# Could not parse: 'C51H90NO10P'
# Could not parse: 'C51H92NO10P'
# Could not parse: 'C51H92O13P2'
# Could not parse: 'C52H94N2O18'
# Could not parse: 'C53H90N2O16'
# Could not parse: 'C53H91NO8'
# Could not parse: 'C53H93NO8'
# Could not parse: 'C53H94NO7P'
# Could not parse: 'C55H92N2O16'
# Could not parse: 'C55H98NO7P'
# Could not parse: 'C56H82O6S'
# Could not parse: 'C56H89O10P'
# Could not parse: 'C57H99O7P'
# Could not parse: 'C57H101O7P'
# Could not parse: 'C58H94NO10P'
# 1 / 30
# 2 / 30
# 3 / 30
# 4 / 30
# 5 / 30
# 6 / 30
# 7 / 30
# 8 / 30
# 9 / 30
# 10 / 30
# 11 / 30
# 12 / 30
# 13 / 30
# 14 / 30
# 15 / 30
# 16 / 30
# 17 / 30
# 18 / 30
# 19 / 30
# 20 / 30
# 21 / 30
# 22 / 30
# 23 / 30
# 24 / 30
# 25 / 30
# 26 / 30
# 27 / 30
# 28 / 30
# 29 / 30
# 30 / 30
# /home/mklein/linex2_for_maldi/linex2metaspace/build_network.py:54: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series(out_l, index=all_lipids.index)

# %%
print(linex_path)
# Out:
# /home/mklein/Dropouts/linex/Lx_Pancreatic_Cancer.graphml
